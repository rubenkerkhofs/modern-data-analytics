# %%
import geopandas as gpd
import os
import zipfile as zf
import geopandas
from shapely.geometry import shape
import gzip 
import urllib.request
import xarray as xr
import io
import shapefile
import pandas as pd

# %%
zp = zf.ZipFile('TM_WORLD_BORDERS-0.3.zip')
files_to_read = [y for y in zp.namelist() for ending in ['dbf', 'prj', 'shp', 'shx'] if y.endswith(ending)]
dummy = zp.read(files_to_read[0])
dbf_file, prj_file, shp_file, shx_file = [zp.open(filename) for filename in files_to_read]
r = shapefile.Reader(shp = shp_file, shx = shx_file, dbf = dbf_file, encoding='windows-1252')
attributes, geometry = [], []
field_names = [field[0] for field in r.fields[1:]]
for row in r.shapeRecords():
    geometry.append(shape(row.shape.__geo_interface__))
    attributes.append(dict(zip(field_names, row.record)))

# %%
gdf = gpd.GeoDataFrame(data = attributes, geometry = geometry)

# %%
gdf
# Out:
#     FIPS ISO2 ISO3   UN                                  NAME    AREA  \
# 0     AC   AG  ATG   28                   Antigua and Barbuda      44
# 1     AG   DZ  DZA   12                               Algeria  238174
# 2     AJ   AZ  AZE   31                            Azerbaijan    8260
# 3     AL   AL  ALB    8                               Albania    2740
# 4     AM   AM  ARM   51                               Armenia    2820
# ..   ...  ...  ...  ...                                   ...     ...
# 241   TB   BL  BLM  652                      Saint Barthelemy       0
# 242   GK   GG  GGY  831                              Guernsey       0
# 243   JE   JE  JEY  832                                Jersey       0
# 244   SX   GS  SGS  239  South Georgia South Sandwich Islands       0
# 245   TW   TW  TWN  158                                Taiwan       0
#
#       POP2005  REGION  SUBREGION      LON     LAT  \
# 0       83039      19         29  -61.783  17.078
# 1    32854159       2         15    2.632  28.163
# 2     8352021     142        145   47.395  40.430
# 3     3153731     150         39   20.068  41.143
# 4     3017661     142        145   44.563  40.534
# ..        ...     ...        ...      ...     ...
# 241         0      19         29  -63.043  18.040
# 242         0     150        154   -2.576  49.459
# 243         0     150        154   -2.129  49.219
# 244         0       0          0  -36.891 -54.209
# 245         0       0          0  120.946  23.754
#
#                                               geometry
# 0    MULTIPOLYGON (((-61.68667 17.02444, -61.73806 ...
# 1    POLYGON ((2.96361 36.80222, 2.98139 36.80694, ...
# 2    MULTIPOLYGON (((45.08332 39.76804, 45.26639 39...
# 3    POLYGON ((19.43621 41.02107, 19.45055 41.06000...
# 4    MULTIPOLYGON (((45.57305 40.63249, 45.52888 40...
# ..                                                 ...
# 241  POLYGON ((-63.02834 18.01555, -63.03334 18.015...
# 242  POLYGON ((-2.59083 49.42249, -2.59722 49.42249...
# 243  POLYGON ((-2.01500 49.21416, -2.02111 49.17722...
# 244  MULTIPOLYGON (((-27.32584 -59.42722, -27.29806...
# 245  MULTIPOLYGON (((121.57639 22.00139, 121.57027 ...
#
# [246 rows x 12 columns]

# %% [markdown]
# Scraping does not work on my laptop now :

# %%
 import pandasdmx as sdmx

# %%
url = "https://data.giss.nasa.gov/pub/gistemp/gistemp1200_GHCNv4_ERSSTv5.nc.gz"
req2 = urllib.request.Request(url)
with gzip.open(urllib.request.urlopen(req2)) as resp2:
    xr_df2 = xr.open_dataset(io.BytesIO(resp2.read()))
df4 = xr_df2.to_dataframe()
dfnasa = df4.reset_index()

# %% [markdown]
# Let's try a nn to predict heatwaves: Input signals tmeprature but also maybe umidity and stuff FOR ALL COUNTRY

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pandas as pd
import os
from sklearn.preprocessing import MinMaxScaler

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, GRU, Embedding
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras.backend import square, mean

# %%
dfnasa2 = dfnasa.dropna()

# %%
dfnasa2['tempanomaly'].plot()
# Out:
# <AxesSubplot:>

# %%
gdf2 = df2[df2['time'].dt.year > 2000]
del df2
del df
gdf2 = gpd.GeoDataFrame(
    gdf2, geometry=gpd.points_from_xy(gdf2.lat, gdf2.lon))

# %%
nasa50 = dfnasa[dfnasa['time'].dt.year > 1950]
nasa50 = gpd.GeoDataFrame(
    nasa50, geometry=gpd.points_from_xy(nasa50.lat, nasa50.lon))

# %%
final_gdf = gpd.sjoin(gdf, gdf2, how="inner")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-c491053445bf> in <module>
# ----> 1 final_gdf = gpd.sjoin(gdf, nasa50, how="inner")
#
# ~\anaconda3\lib\site-packages\geopandas\tools\sjoin.py in sjoin(left_df, right_df, how, op, lsuffix, rsuffix)
#      85     dimension is not taken into account.
#      86     """
# ---> 87     _basic_checks(left_df, right_df, how, lsuffix, rsuffix)
#      88
#      89     indices = _geom_predicate_query(left_df, right_df, op)
#
# ~\anaconda3\lib\site-packages\geopandas\tools\sjoin.py in _basic_checks(left_df, right_df, how, lsuffix, rsuffix)
#     118
#     119     if not isinstance(right_df, GeoDataFrame):
# --> 120         raise ValueError(
#     121             "'right_df' should be GeoDataFrame, got {}".format(type(right_df))
#     122         )
#
# ValueError: 'right_df' should be GeoDataFrame, got <class 'pandas.core.frame.DataFrame'>

# %%
final_gdf
# Out:
#     FIPS ISO2 ISO3   UN      NAME    AREA   POP2005  REGION  SUBREGION  \
# 1     AG   DZ  DZA   12   Algeria  238174  32854159       2         15
# 1     AG   DZ  DZA   12   Algeria  238174  32854159       2         15
# 1     AG   DZ  DZA   12   Algeria  238174  32854159       2         15
# 1     AG   DZ  DZA   12   Algeria  238174  32854159       2         15
# 1     AG   DZ  DZA   12   Algeria  238174  32854159       2         15
# ..   ...  ...  ...  ...       ...     ...       ...     ...        ...
# 239   SV   SJ  SJM  744  Svalbard       0         0     150        154
# 239   SV   SJ  SJM  744  Svalbard       0         0     150        154
# 239   SV   SJ  SJM  744  Svalbard       0         0     150        154
# 239   SV   SJ  SJM  744  Svalbard       0         0     150        154
# 239   SV   SJ  SJM  744  Svalbard       0         0     150        154
#
#         LON     LAT                                           geometry  \
# 1     2.632  28.163  POLYGON ((2.96361 36.80222, 2.98139 36.80694, ...
# 1     2.632  28.163  POLYGON ((2.96361 36.80222, 2.98139 36.80694, ...
# 1     2.632  28.163  POLYGON ((2.96361 36.80222, 2.98139 36.80694, ...
# 1     2.632  28.163  POLYGON ((2.96361 36.80222, 2.98139 36.80694, ...
# 1     2.632  28.163  POLYGON ((2.96361 36.80222, 2.98139 36.80694, ...
# ..      ...     ...                                                ...
# 239  18.374  78.830  MULTIPOLYGON (((-8.29089 70.97415, -8.39447 70...
# 239  18.374  78.830  MULTIPOLYGON (((-8.29089 70.97415, -8.39447 70...
# 239  18.374  78.830  MULTIPOLYGON (((-8.29089 70.97415, -8.39447 70...
# 239  18.374  78.830  MULTIPOLYGON (((-8.29089 70.97415, -8.39447 70...
# 239  18.374  78.830  MULTIPOLYGON (((-8.29089 70.97415, -8.39447 70...
#
#      index_right   lat   lon  nv       time  time_bnds  tempanomaly
# 1       27841492   1.0  35.0   1 2017-09-15 2017-10-01         2.20
# 1       27841493   1.0  35.0   1 2017-10-15 2017-11-01         1.08
# 1       27841494   1.0  35.0   1 2017-11-15 2017-12-01         0.62
# 1       27841495   1.0  35.0   1 2017-12-15 2018-01-01         0.82
# 1       27841496   1.0  35.0   1 2018-01-15 2018-02-01         0.50
# ..           ...   ...   ...  ..        ...        ...          ...
# 239     32795529  17.0  77.0   0 2019-06-15 2019-06-01         1.68
# 239     32795530  17.0  77.0   0 2019-07-15 2019-07-01         0.98
# 239     32795531  17.0  77.0   0 2019-08-15 2019-08-01         0.53
# 239     32795532  17.0  77.0   0 2019-09-15 2019-09-01         0.24
# 239     32795533  17.0  77.0   0 2019-10-15 2019-10-01         0.28
#
# [401024 rows x 19 columns]
